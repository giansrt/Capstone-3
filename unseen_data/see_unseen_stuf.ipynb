# %%
import pandas as pd

# %%
df1 = pd.read_csv('housing.csv')
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df_real = pd.read_csv('data_california_house.csv')
df_real
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -119.79     36.73                52.0        112.0            28.0
# 1        -122.21     37.77                43.0       1017.0           328.0
# 2        -118.04     33.87                17.0       2358.0           396.0
# 3        -118.28     34.06                17.0       2518.0          1196.0
# 4        -119.81     36.73                50.0        772.0           194.0
# ...          ...       ...                 ...          ...             ...
# 14443    -121.26     38.27                20.0       1314.0           229.0
# 14444    -120.89     37.48                27.0       1118.0           195.0
# 14445    -121.90     36.58                31.0       1431.0             NaN
# 14446    -117.93     33.62                34.0       2125.0           498.0
# 14447    -115.56     32.80                15.0       1171.0           328.0
#
# ...

# %%
df1.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
columns = df_real.columns

# %%
df1 = df1[columns]

# %%
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df1_count = df1.value_counts().reset_index(name="count_df1")
df1_count.shape[0]
# Out:
# 20433

# %%
# Merging DataFrames to find non-matching rows
df_merge = df1.merge(df_real, how='outer', indicator=True)

df_merge
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
# Filtering to get rows that are only in A
df_result = df_merge[df_merge['_merge'] == 'left_only'].drop(columns='_merge')

df_result
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7        -122.25     37.84                52.0       3104.0           687.0
# 8        -122.26     37.84                42.0       2555.0           665.0
# 12       -122.26     37.85                52.0       2491.0           474.0
# 16       -122.27     37.85                52.0       1966.0           347.0
# 18       -122.26     37.84                50.0       2239.0           455.0
# ...          ...       ...                 ...          ...             ...
# 20623    -121.37     39.03                32.0       1158.0           244.0
# 20625    -121.52     39.12                37.0        102.0            17.0
# 20626    -121.43     39.18                36.0       1124.0           184.0
# 20629    -121.39     39.12                28.0      10035.0          1856.0
# 20630    -121.32     39.29                11.0       2640.0           505.0
#
# ...

# %%
df_result.to_csv('test_data_housing.csv',index=False)
